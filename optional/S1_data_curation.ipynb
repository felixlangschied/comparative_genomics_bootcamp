# %% [markdown]
# ## Data curation

# %%
taxa = [
    "Homo_sapiens", 
    "Pan_troglodytes", 
    "Gorilla_gorilla", 
    "Macaca_mulatta", 
    "Aotus_nancymaae", 
    "Oryctolagus_cuniculus", 
    "Mus_musculus", 
    "Cavia_porcellus", 
    "Felis_catus", 
    "Canis_lupus_familiaris", 
    "Pipistrellus_kuhlii", 
    "Equus_caballus", 
    "Bos_taurus", 
    "Sus_scrofa", 
    "Loxodonta_africana", 
    "Monodelphis_domestica", 
    "Ornithorhynchus_anatinus", 
    "Gallus_gallus", 
    "Passer_montanus", 
    "Anolis_carolinensis", 
    "Xenopus_tropicalis",
]

print(len(taxa))
# Out:
# 21

# %%
# %%bash
#
# datasets download gene taxon human --include protein
# Out:
# ...
# ...
# ...
# Process is interrupted.
